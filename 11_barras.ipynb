# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
produtos = ["Lápis", "Canetas", "Borrachas", "Tesouras"]
vendas = [25, 19, 9, 14]

# %%
plt.bar(produtos, vendas)
plt.show()

# %%
funcionarios = ["Analista", "Cientista", "Engenheiro", "Arquiteto"]
frequencia = [8, 5, 12, 1]

# %%
plt.bar(funcionarios, frequencia)
plt.show()

# %%
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
tbl_iris = df.pivot_table(values='Sepal.Length', index='Species', aggfunc='mean').\
    sort_values(by='Sepal.Length', ascending=False).reset_index()

tbl_iris
# Out:
#       Species  Sepal.Length
# 0   virginica         6.588
# 1  versicolor         5.936
# 2      setosa         5.006

# %%
plt.bar(tbl_iris['Species'], tbl_iris['Sepal.Length'])
plt.show()
