# %%
import matplotlib.pyplot as plt

# %%
vendas = [28, 32, 25, 1983, 29, 27, 35]

# %%
plt.plot(vendas)
plt.yscale("symlog")
plt.show()

# %%
x = [10, 22, 18, 16, 4215, 26]
y = [10, 21, 19, 17, 18, 18]
plt.plot(x, y, "o")
plt.xscale('log')
plt.show()
